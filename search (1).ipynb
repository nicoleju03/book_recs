# %%
# !wc -l goodreads_books.json.gz
# Out:
#  7588375 goodreads_books.json.gz

# %%
# !ls -lh | grep goodreads_books.json.gz
# Out:
# -rw-r--r--  1 nicoleju  staff   1.9G Sep 28 14:58 goodreads_books.json.gz

# %%
import gzip

#stream file without unzipping, don't have to use memory bc so big
with gzip.open("goodreads_books.json.gz", 'r') as f:
    line = f.readline()

# %%
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %%
import json
data = json.loads(line) #turns to python dictionary
data
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields(line):
    #takes a single line and returns the fields we care about
    data = json.loads(line) # turns json to python dict, then we make a smaller dict from that dict
    return {
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"]
    }

# %%
books_titles =  []
with gzip.open("goodreads_books.json.gz") as f:
    while True:
        line = f.readline()
        if not line:
            break
        fields = parse_fields(line)
        try:
            ratings = int(fields["ratings"]) #only want books with certain number of ratings
        except ValueError:
            continue
        if ratings > 15:
            books_titles.append(fields)

# %%
import pandas as pd
titles = pd.DataFrame.from_dict(books_titles) #books_titles is list of dictionaries
#from dict method will turn each dictionary into a row

# %%
titles["ratings"] = pd.to_numeric(titles["ratings"]) #convert to numeric column

# %%
#need to process titles eg can have diff capitalization
titles["mod_title"] = titles["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          The Unschooled Wizard Sun Wolf and Starhawk 12
# 1                                    Best Friends Forever
# 2                           The Aeneid for Boys and Girls
# 3        Alls Fairy in Love and War Avalon Web of Magic 8
# 4                                     The Devils Notebook
# ...                                                   ...
# 1308952                          Ondine Ondine Quartet 05
# 1308953     Jacqueline Kennedy Onassis Friend of the Arts
# 1308954                   The Spaniards Blackmailed Bride
# 1308955           The Childrens Classic Poetry Collection
# 1308956               101 Nights Volume One 101 Nights 13
#
# [1308957 rows x 6 columns]

# %%
titles["mod_title"] = titles["mod_title"].str.lower() #str is pandas function

# %%
titles["mod_title"] = titles["mod_title"].str.replace("\s+"," ", regex=True) #replace multiple spaces with one space

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1308957 rows x 6 columns]

# %%
# remove rows where mod titles is null
titles = titles[titles["mod_title"].str.len()>0]

# %%
titles.to_json("books_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1302659 rows x 6 columns]

# %%
#turn title into set of numbers, map to search query, figure out how similar?
#term frequency matrix: takes all the unique words across all titles and turns each into a column in the matrix
#titles on left, go through each title, if the word exists in the title, add 1
#lowercases/minimizing extraneous characters = less discrepancies

#then inverse document frequency matrix
#words that appear infrequently = more meaningful (eg "the" is in a bunch of titles, don't want it to be too meaningful)

#multiple term frequency by inverse document frequency

#when searching, build tfid table for the query, compare to the rows of the big tfid to see which are most similar

# %%
# !pip3 install -U scikit-learn scipy matplotlib
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.1-cp310-cp310-macosx_10_9_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 19.5 MB/s eta 0:00:0000:010:01
# Collecting scipy
#   Downloading scipy-1.11.3-cp310-cp310-macosx_10_9_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 10.2 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp310-cp310-macosx_10_12_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 14.2 MB/s eta 0:00:0000:0100:01
# Collecting numpy<2.0,>=1.17.3
#   Downloading numpy-1.26.0-cp310-cp310-macosx_10_9_x86_64.whl (20.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 20.9 MB/s eta 0:00:0000:0100:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 KB 7.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: packaging>=20.0 in /Users/nicoleju/Library/Python/3.10/lib/python/site-packages (from matplotlib) (23.1)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.1-cp310-cp310-macosx_10_10_x86_64.whl (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 15.2 MB/s eta 0:00:0000:0100:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-macosx_10_9_x86_64.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 KB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nicoleju/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 KB 3.6 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp310-cp310-macosx_10_9_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.5 MB/s eta 0:00:0000:0100:01
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp310-cp310-macosx_10_9_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.2/247.2 KB 3.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: six>=1.5 in /Users/nicoleju/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: threadpoolctl, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, contourpy, scikit-learn, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.11.0 fonttools-4.42.1 joblib-1.3.2 kiwisolver-1.4.5 matplotlib-3.8.0 numpy-1.26.0 pillow-10.0.1 pyparsing-3.1.1 scikit-learn-1.3.1 scipy-1.11.3 threadpoolctl-3.2.0
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
#takes list of strings and turns it into that matrix
tfidf = vectorizer.fit_transform(titles["mod_title"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    #pandas thing, lets you style with html
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)
    
def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten() #search tfidf matrix for your search query
    #tell you how much each row in the matrix is similar?
    indices = np.argpartition(similarity, -10)[-10:] #find indices of the 10 highest similarity values
    #use those indices to index titles
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return results.head(5).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
search("milk and honney", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e58c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e58c1_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_e58c1_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_e58c1_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_e58c1_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_e58c1_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_e58c1_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e58c1_level0_row0" class="row_heading level0 row0" >279210</th>
#       <td id="T_e58c1_row0_col0" class="data row0 col0" >33246653</td>
#       <td id="T_e58c1_row0_col1" class="data row0 col1" >Milk and Honey</td>
#       <td id="T_e58c1_row0_col2" class="data row0 col2" >344</td>
#       <td id="T_e58c1_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/33246653-milk-and-honey">Goodreads</a></td>
#       <td id="T_e58c1_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1480919673m/33246653.jpg" width=50></img></td>
#       <td id="T_e58c1_row0_col5" class="data row0 col5" >milk and honey</td>
#     </tr>
#     <tr>
#       <th id="T_e58c1_level0_row1" class="row_heading level0 row1" >1096991</th>
#       <td id="T_e58c1_row1_col0" class="data row1 col0" >29825932</td>
#       <td id="T_e58c1_row1_col1" class="data row1 col1" >Blood & Milk</td>
#       <td id="T_e58c1_row1_col2" class="data row1 col2" >280</td>
#       <td id="T_e58c1_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/29825932-blood-milk">Goodreads</a></td>
#       <td id="T_e58c1_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1464336218m/29825932.jpg" width=50></img></td>
#       <td id="T_e58c1_row1_col5" class="data row1 col5" >blood milk</td>
#     </tr>
#     <tr>
#       <th id="T_e58c1_level0_row2" class="row_heading level0 row2" >583391</th>
#       <td id="T_e58c1_row2_col0" class="data row2 col0" >391991</td>
#       <td id="T_e58c1_row2_col1" class="data row2 col1" >Milk</td>
#       <td id="T_e58c1_row2_col2" class="data row2 col2" >209</td>
#       <td id="T_e58c1_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/391991.Milk">Goodreads</a></td>
#       <td id="T_e58c1_row2_col4" class="data row2 col4" ><img src="https://images.gr-assets.com/books/1312051673m/391991.jpg" width=50></img></td>
#       <td id="T_e58c1_row2_col5" class="data row2 col5" >milk</td>
#     </tr>
#     <tr>
#       <th id="T_e58c1_level0_row3" class="row_heading level0 row3" >514796</th>
#       <td id="T_e58c1_row3_col0" class="data row3 col0" >34583011</td>
#       <td id="T_e58c1_row3_col1" class="data row3 col1" >Milk and Honey</td>
#       <td id="T_e58c1_row3_col2" class="data row3 col2" >118</td>
#       <td id="T_e58c1_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/34583011-milk-and-honey">Goodreads</a></td>
#       <td id="T_e58c1_row3_col4" class="data row3 col4" ><img src="https://images.gr-assets.com/books/1489497855m/34583011.jpg" width=50></img></td>
#       <td id="T_e58c1_row3_col5" class="data row3 col5" >milk and honey</td>
#     </tr>
#     <tr>
#       <th id="T_e58c1_level0_row4" class="row_heading level0 row4" >94899</th>
#       <td id="T_e58c1_row4_col0" class="data row4 col0" >30528538</td>
#       <td id="T_e58c1_row4_col1" class="data row4 col1" >Blood & Milk</td>
#       <td id="T_e58c1_row4_col2" class="data row4 col2" >115</td>
#       <td id="T_e58c1_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/30528538-blood-milk">Goodreads</a></td>
#       <td id="T_e58c1_row4_col4" class="data row4 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_e58c1_row4_col5" class="data row4 col5" >blood milk</td>
#     </tr>
#   </tbody>
# </table>

# %%
#only take the row with highest number of ratings

# %%
#take book ids and make a list of liked books
liked_books = ["2657", "6066095", "33246653" ]
